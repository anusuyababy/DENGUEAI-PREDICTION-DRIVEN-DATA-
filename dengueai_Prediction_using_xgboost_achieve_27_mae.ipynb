# %% [markdown]
# # PREDICTION

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## TRAIN SET

# %%
train=pd.read_csv('train.csv')
train.head()
# Out:
#   city  year  weekofyear  ... station_min_temp_c  station_precip_mm  total_cases
# 0   sj  1990          18  ...               20.0               16.0            4
# 1   sj  1990          19  ...               22.2                8.6            5
# 2   sj  1990          20  ...               22.8               41.4            4
# 3   sj  1990          21  ...               23.3                4.0            3
# 4   sj  1990          22  ...               23.9                5.8            6
#
# [5 rows x 25 columns]

# %%
train.tail()
# Out:
#      city  year  weekofyear  ... station_min_temp_c  station_precip_mm  total_cases
# 1451   iq  2010          21  ...               22.4               27.0            5
# 1452   iq  2010          22  ...               21.7               36.6            8
# 1453   iq  2010          23  ...               19.2                7.4            1
# 1454   iq  2010          24  ...               21.0               16.0            1
# 1455   iq  2010          25  ...               22.2               20.4            4
#
# [5 rows x 25 columns]

# %%
train.shape
# Out:
# (1456, 25)

# %%
train.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# ...

# %%
train.total_cases.value_counts()
# Out:
# 0      100
# 6       71
# 3       70
# 5       70
# 2       69
#       ...
# 135      1
# 137      1
# 141      1
# 142      1
# 461      1
# Name: total_cases, Length: 135, dtype: int64

# %% [markdown]
# ## TEST DATASET

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#   city  year  ...  station_min_temp_c station_precip_mm
# 0   sj  2008  ...                21.7              75.2
# 1   sj  2008  ...                22.2              34.3
# 2   sj  2008  ...                22.8               3.0
# 3   sj  2008  ...                24.4               0.3
# 4   sj  2008  ...                23.3              84.1
#
# [5 rows x 24 columns]

# %%
test.shape
# Out:
# (416, 24)

# %%
test.isnull().sum()
# Out:
# city                                      0
# year                                      0
# weekofyear                                0
# week_start_date                           0
# ndvi_ne                                  43
# ndvi_nw                                  11
# ndvi_se                                   1
# ndvi_sw                                   1
# precipitation_amt_mm                      2
# reanalysis_air_temp_k                     2
# reanalysis_avg_temp_k                     2
# reanalysis_dew_point_temp_k               2
# reanalysis_max_air_temp_k                 2
# reanalysis_min_air_temp_k                 2
# reanalysis_precip_amt_kg_per_m2           2
# reanalysis_relative_humidity_percent      2
# reanalysis_sat_precip_amt_mm              2
# reanalysis_specific_humidity_g_per_kg     2
# reanalysis_tdtr_k                         2
# station_avg_temp_c                       12
# station_diur_temp_rng_c                  12
# ...

# %% [markdown]
# ## HANDLING MISSING VALUES FOR BOTH TRAIN AND TEST DATA

# %%
train['train_or_test']='train'
test['train_or_test']='test'
df=pd.concat([train,test])

# %%
df.head()
# Out:
#   city  year  weekofyear  ... station_precip_mm  total_cases  train_or_test
# 0   sj  1990          18  ...              16.0          4.0          train
# 1   sj  1990          19  ...               8.6          5.0          train
# 2   sj  1990          20  ...              41.4          4.0          train
# 3   sj  1990          21  ...               4.0          3.0          train
# 4   sj  1990          22  ...               5.8          6.0          train
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1872 entries, 0 to 415
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1872 non-null   object
#  1   year                                   1872 non-null   int64
#  2   weekofyear                             1872 non-null   int64
#  3   week_start_date                        1872 non-null   object
#  4   ndvi_ne                                1635 non-null   float64
#  5   ndvi_nw                                1809 non-null   float64
#  6   ndvi_se                                1849 non-null   float64
#  7   ndvi_sw                                1849 non-null   float64
#  8   precipitation_amt_mm                   1857 non-null   float64
#  9   reanalysis_air_temp_k                  1860 non-null   float64
# ...

# %%
#filling missing values using interpolate function
#df.interpolate(inplace=True)

# %%
def impute_nan(df, feat):
  m = df[feat].median()
  df[feat] = df[feat].fillna(m)

# %%
col = ['ndvi_ne', 'ndvi_nw',
       'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
       'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
       'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
       'reanalysis_precip_amt_kg_per_m2',
       'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
       'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
       'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
       'station_min_temp_c', 'station_precip_mm']

# %%
for feat in col:
  impute_nan(df, feat)

# %%
df.head()
# Out:
#   city  year  weekofyear  ... station_precip_mm  total_cases  train_or_test
# 0   sj  1990          18  ...              16.0          4.0          train
# 1   sj  1990          19  ...               8.6          5.0          train
# 2   sj  1990          20  ...              41.4          4.0          train
# 3   sj  1990          21  ...               4.0          3.0          train
# 4   sj  1990          22  ...               5.8          6.0          train
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                    0
# ndvi_nw                                    0
# ndvi_se                                    0
# ndvi_sw                                    0
# precipitation_amt_mm                       0
# reanalysis_air_temp_k                      0
# reanalysis_avg_temp_k                      0
# reanalysis_dew_point_temp_k                0
# reanalysis_max_air_temp_k                  0
# reanalysis_min_air_temp_k                  0
# reanalysis_precip_amt_kg_per_m2            0
# reanalysis_relative_humidity_percent       0
# reanalysis_sat_precip_amt_mm               0
# reanalysis_specific_humidity_g_per_kg      0
# reanalysis_tdtr_k                          0
# station_avg_temp_c                         0
# station_diur_temp_rng_c                    0
# ...

# %% [markdown]
# ## EDA

# %%
df.columns
# Out:
# Index(['city', 'year', 'weekofyear', 'week_start_date', 'ndvi_ne', 'ndvi_nw',
#        'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm', 'total_cases',
#        'train_or_test'],
#       dtype='object')

# %%
#col = ['reanalysis_air_temp_k', 'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k', 'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k']

# %%
#def convert_kelvin_to_celsius(df, col):
  #df[col] = df[col] - 273.15

# %%
#convert_kelvin_to_celsius(df, col)
df.head()
# Out:
#   city  year  weekofyear  ... station_precip_mm  total_cases  train_or_test
# 0   sj  1990          18  ...              16.0          4.0          train
# 1   sj  1990          19  ...               8.6          5.0          train
# 2   sj  1990          20  ...              41.4          4.0          train
# 3   sj  1990          21  ...               4.0          3.0          train
# 4   sj  1990          22  ...               5.8          6.0          train
#
# [5 rows x 26 columns]

# %%
#col = ['reanalysis_relative_humidity_percent']

# %%
#def convert_to_percent(df, col):
  #df[col] = df[col] /100

# %%
#convert_to_percent(df, col)
df.head()
# Out:
#   city  year  weekofyear  ... station_precip_mm  total_cases  train_or_test
# 0   sj  1990          18  ...              16.0          4.0          train
# 1   sj  1990          19  ...               8.6          5.0          train
# 2   sj  1990          20  ...              41.4          4.0          train
# 3   sj  1990          21  ...               4.0          3.0          train
# 4   sj  1990          22  ...               5.8          6.0          train
#
# [5 rows x 26 columns]

# %% [markdown]
# ## FEATURE ENGINEERING

# %% [markdown]
# ## TRAIN DATA

# %%
df.city.value_counts()
# Out:
# sj    1196
# iq     676
# Name: city, dtype: int64

# %%
g = {'sj' : 0, 'iq' : 1}
df['city'] = df['city'].map(g)
df.head()
# Out:
#    city  year  weekofyear  ... station_precip_mm  total_cases  train_or_test
# 0     0  1990          18  ...              16.0          4.0          train
# 1     0  1990          19  ...               8.6          5.0          train
# 2     0  1990          20  ...              41.4          4.0          train
# 3     0  1990          21  ...               4.0          3.0          train
# 4     0  1990          22  ...               5.8          6.0          train
#
# [5 rows x 26 columns]

# %%
df = df.drop(['week_start_date'], axis=1)
df.head()
# Out:
#    city  year  weekofyear  ...  station_precip_mm  total_cases  train_or_test
# 0     0  1990          18  ...               16.0          4.0          train
# 1     0  1990          19  ...                8.6          5.0          train
# 2     0  1990          20  ...               41.4          4.0          train
# 3     0  1990          21  ...                4.0          3.0          train
# 4     0  1990          22  ...                5.8          6.0          train
#
# [5 rows x 25 columns]

# %%
col = ['year', 'weekofyear']

# %%
#for feature in col:
    #labels_ordered=df[feature].value_counts().to_dict()
    #labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    #df[feature]=df[feature].map(labels_ordered)
df.head()
# Out:
#    city  year  weekofyear  ...  station_precip_mm  total_cases  train_or_test
# 0     0  1990          18  ...               16.0          4.0          train
# 1     0  1990          19  ...                8.6          5.0          train
# 2     0  1990          20  ...               41.4          4.0          train
# 3     0  1990          21  ...                4.0          3.0          train
# 4     0  1990          22  ...                5.8          6.0          train
#
# [5 rows x 25 columns]

# %% [markdown]
# ## TEST DATA

# %% [markdown]
# ## FEATURE SCALING (BOTH NORMALIZATION AND STANDARDISATION)

# %%
train.columns
# Out:
# Index(['city', 'year', 'weekofyear', 'week_start_date', 'ndvi_ne', 'ndvi_nw',
#        'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm', 'total_cases',
#        'train_or_test'],
#       dtype='object')

# %%
columns_to_scale=['city', 'year', 'weekofyear', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
       'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
       'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
       'reanalysis_precip_amt_kg_per_m2',
       'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
       'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
       'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
       'station_min_temp_c', 'station_precip_mm']

# %%
#from sklearn.preprocessing import StandardScaler
#scaler=StandardScaler()
#df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])
df.head()
# Out:
#    city  year  weekofyear  ...  station_precip_mm  total_cases  train_or_test
# 0     0  1990          18  ...               16.0          4.0          train
# 1     0  1990          19  ...                8.6          5.0          train
# 2     0  1990          20  ...               41.4          4.0          train
# 3     0  1990          21  ...                4.0          3.0          train
# 4     0  1990          22  ...                5.8          6.0          train
#
# [5 rows x 25 columns]

# %%
train=df.loc[df.train_or_test.isin(['train'])]
test=df.loc[df.train_or_test.isin(['test'])]
train.drop(columns={'train_or_test'},axis=1,inplace=True)
test.drop(columns={'train_or_test'},axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train.head()
# Out:
#    city  year  weekofyear  ...  station_min_temp_c  station_precip_mm  total_cases
# 0     0  1990          18  ...                20.0               16.0          4.0
# 1     0  1990          19  ...                22.2                8.6          5.0
# 2     0  1990          20  ...                22.8               41.4          4.0
# 3     0  1990          21  ...                23.3                4.0          3.0
# 4     0  1990          22  ...                23.9                5.8          6.0
#
# [5 rows x 24 columns]

# %%
test.head()
# Out:
#    city  year  weekofyear  ...  station_min_temp_c  station_precip_mm  total_cases
# 0     0  2008          18  ...                21.7               75.2          NaN
# 1     0  2008          19  ...                22.2               34.3          NaN
# 2     0  2008          20  ...                22.8                3.0          NaN
# 3     0  2008          21  ...                24.4                0.3          NaN
# 4     0  2008          22  ...                23.3               84.1          NaN
#
# [5 rows x 24 columns]

# %%
x_train=train.loc[:,['city', 'year', 'weekofyear', 'ndvi_ne', 'ndvi_nw', 'ndvi_se',
       'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
       'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
       'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
       'reanalysis_precip_amt_kg_per_m2',
       'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
       'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
       'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
       'station_min_temp_c', 'station_precip_mm']]
y_train=train.loc[:,['total_cases']]
test=test.loc[:,['city', 'year', 'weekofyear', 'ndvi_ne', 'ndvi_nw', 'ndvi_se',
       'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
       'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
       'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
       'reanalysis_precip_amt_kg_per_m2',
       'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
       'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
       'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
       'station_min_temp_c', 'station_precip_mm']]

# %% [markdown]
# ## TRAIN DATA

# %%
from xgboost.sklearn import XGBRegressor
clf=XGBRegressor(n_estimators=1000,learning_rate=0.02,gamma=0,min_child_weight=30,
                           subsample=0.8,colsample_bytree=1,max_depth=7)
clf.fit(x_train, y_train)
# Out:
# [16:09:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.02, max_delta_step=0,
#              max_depth=7, min_child_weight=30, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=0.8, verbosity=1)

# %%
total_cases = clf.predict(test)
total_cases
# Out:
# array([ 5.52733994e+00,  1.14750350e+00,  7.07127094e+00,  1.30106277e+01,
#         1.52679415e+01,  1.09437542e+01,  1.75285587e+01,  1.19640312e+01,
#         1.65957184e+01,  1.86432095e+01,  2.02012024e+01,  1.62190628e+01,
#         2.86244907e+01,  1.89627838e+01,  4.41912766e+01,  4.64656754e+01,
#         2.67620277e+01,  7.12048645e+01,  1.11657326e+02,  6.62962418e+01,
#         6.84383163e+01,  5.51922226e+01,  4.25916023e+01,  6.51545563e+01,
#         4.18490410e+01,  2.69943714e+01,  3.60247688e+01,  2.93275433e+01,
#         4.48333855e+01,  3.92230339e+01,  2.86825981e+01,  1.55603065e+01,
#         1.55853443e+01,  6.13080740e+00,  5.60622644e+00,  1.37488813e+01,
#         1.62877350e+01,  2.02248096e+01,  1.39313164e+01,  1.46406937e+01,
#         9.25949574e+00,  1.26648722e+01,  1.22682943e+01,  1.08971395e+01,
#         4.47226238e+00,  5.70949554e+00,  1.51632369e+00,  1.12858367e+00,
# ...

# %%
clf.score(x_train, y_train)
# Out:
# 0.9597273965512534

# %%
total_cases = clf.predict(test).round().astype(int)
total_cases
# Out:
# array([  6,   1,   7,  13,  15,  11,  18,  12,  17,  19,  20,  16,  29,
#         19,  44,  46,  27,  71, 112,  66,  68,  55,  43,  65,  42,  27,
#         36,  29,  45,  39,  29,  16,  16,   6,   6,  14,  16,  20,  14,
#         15,   9,  13,  12,  11,   4,   6,   2,   1,   0,   2,   3,   3,
#          6,   1,  14,   4,  10,  11,  10,   9,   5,  20,  29,  26,  31,
#         28,  42,  35,  27,  73,  57,  22,  38,  52,  68,  66,  56,  30,
#         53,  39,  24,  52,  43,  27,  20,   9,  20,  11,  20,  22,  15,
#         17,  14,  14,  16,  10,  17,   4,   1,   5,  11,   4,   4,   8,
#          9,  23,  17,  14,  11,  34,  41,  25,  28,  29,  42,  68,  35,
#         36,  37,  88,  88,  86,  93,  78,  68,  57,  42,  51,  76,  59,
#         64,  37,  38,  32,  26,  28,  21,  26,   9,   4,  21,  17,  20,
#         17,  12,  12,  11,   9,  10,   4,   6,   3,   5,   5,   5,  -2,
#          3,  16,   3,   2,   8,  24,  20,  25,  28,  36,  19,  23,  26,
# ...

# %%
 total_cases= np.where(total_cases < 0, 0, total_cases)
 total_cases
# Out:
# array([  6,   1,   7,  13,  15,  11,  18,  12,  17,  19,  20,  16,  29,
#         19,  44,  46,  27,  71, 112,  66,  68,  55,  43,  65,  42,  27,
#         36,  29,  45,  39,  29,  16,  16,   6,   6,  14,  16,  20,  14,
#         15,   9,  13,  12,  11,   4,   6,   2,   1,   0,   2,   3,   3,
#          6,   1,  14,   4,  10,  11,  10,   9,   5,  20,  29,  26,  31,
#         28,  42,  35,  27,  73,  57,  22,  38,  52,  68,  66,  56,  30,
#         53,  39,  24,  52,  43,  27,  20,   9,  20,  11,  20,  22,  15,
#         17,  14,  14,  16,  10,  17,   4,   1,   5,  11,   4,   4,   8,
#          9,  23,  17,  14,  11,  34,  41,  25,  28,  29,  42,  68,  35,
#         36,  37,  88,  88,  86,  93,  78,  68,  57,  42,  51,  76,  59,
#         64,  37,  38,  32,  26,  28,  21,  26,   9,   4,  21,  17,  20,
#         17,  12,  12,  11,   9,  10,   4,   6,   3,   5,   5,   5,   0,
#          3,  16,   3,   2,   8,  24,  20,  25,  28,  36,  19,  23,  26,
# ...

# %%
test['total_cases'] = total_cases
test.head()
# Out:
#    city  year  weekofyear  ...  station_min_temp_c  station_precip_mm  total_cases
# 0     0  2008          18  ...                21.7               75.2            6
# 1     0  2008          19  ...                22.2               34.3            1
# 2     0  2008          20  ...                22.8                3.0            7
# 3     0  2008          21  ...                24.4                0.3           13
# 4     0  2008          22  ...                23.3               84.1           15
#
# [5 rows x 24 columns]

# %%
test.astype(int)
test.head()
# Out:
#    city  year  weekofyear  ...  station_min_temp_c  station_precip_mm  total_cases
# 0     0  2008          18  ...                21.7               75.2            6
# 1     0  2008          19  ...                22.2               34.3            1
# 2     0  2008          20  ...                22.8                3.0            7
# 3     0  2008          21  ...                24.4                0.3           13
# 4     0  2008          22  ...                23.3               84.1           15
#
# [5 rows x 24 columns]

# %%
print(test['total_cases'].round(0).astype(int))
# Out:
# 0       6
# 1       1
# 2       7
# 3      13
# 4      15
#        ..
# 411     7
# 412     5
# 413     0
# 414     3
# 415     3
# Name: total_cases, Length: 416, dtype: int64

# %%
s= test['total_cases'].round(0).astype(int)

# %%
s
# Out:
# 0       6
# 1       1
# 2       7
# 3      13
# 4      15
#        ..
# 411     7
# 412     5
# 413     0
# 414     3
# 415     3
# Name: total_cases, Length: 416, dtype: int64

# %%
test['g'] = s

# %%
test.head()
# Out:
#    city  year  weekofyear  ...  station_precip_mm  total_cases   g
# 0     0  2008          18  ...               75.2            6   6
# 1     0  2008          19  ...               34.3            1   1
# 2     0  2008          20  ...                3.0            7   7
# 3     0  2008          21  ...                0.3           13  13
# 4     0  2008          22  ...               84.1           15  15
#
# [5 rows x 25 columns]

# %%
test.to_csv('sub.csv')
